# %%
# %reload_ext autoreload
# %autoreload 2
import sys
print(sys.executable)
module_path = os.path.abspath(os.path.join('..'))

# Add the directory to sys.path
if module_path not in sys.path:
    sys.path.append(module_path)
# Verify kernal path
import numpy as np
import pandas as pd
import os
import requests
from dotenv import load_dotenv
from datetime import datetime
load_dotenv()
# Out:
# /Users/pravachanpatra/Documents/PYTHON/AI_ML_DL/Stock_Price_Predictor/venv/bin/python
# True

# %%
HOPSWORKS_PROJECT_NAME = "taxi_demand_pravachan"
HOPSWORKS_API_KEY = os.getenv("HOPSWORKS_API_KEY")

print(datetime.now().date().strftime('%Y-%m-%d'))
# Out:
# 2024-08-05

# %%
from src.data import dowload_one_file_of_raw_data

start_date = "2022-08-02"
end_date = datetime.now().date().strftime('%Y-%m-%d')  # current date

prices = dowload_one_file_of_raw_data(symbol='AAPL', start_date=start_date, end_date=end_date) 
prices
# Out:
# dict_keys(['ticker', 'queryCount', 'resultsCount', 'adjusted', 'results', 'status', 'request_id', 'count'])
# 2024-08-05 22:28:17,402 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#           volume  vw_avr_price  open_price  close_price  high_price  \
# 0     60362338.0      165.8939      166.37       164.87     167.810
# 1     63075503.0      164.8395      164.02       164.92     165.820
# 2     70170540.0      168.3496      167.68       169.24     169.340
# 3     57142109.0      169.3737      170.06       168.49     170.990
# 4     68039382.0      171.0754      169.82       172.10     172.170
# ..           ...           ...         ...          ...         ...
# 495   35153729.0      218.1319      216.96       218.24     219.300
# 496   40681625.0      218.4059      219.19       218.80     220.325
# 497   48422974.0      222.3441      221.44       222.08     223.820
# ...

# %%
from src.data import transform_raw_data_into_ts_data

ts_prices= transform_raw_data_into_ts_data(prices, start_date, end_date)
ts_prices
# Out:
# MISSING DATES
# /Users/pravachanpatra/Documents/PYTHON/AI_ML_DL/Stock_Price_Predictor/venv/lib/python3.12/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#           volume  vw_avr_price  open_price  close_price  high_price  \
# 0     60362338.0      165.8939      166.37       164.87      167.81
# 1     60362338.0      165.8939      166.37       164.87      167.81
# 2     60362338.0      165.8939      166.37       164.87      167.81
# 3     60362338.0      165.8939      166.37       164.87      167.81
# 4     60362338.0      165.8939      166.37       164.87      167.81
# ..           ...           ...         ...          ...         ...
# 730   61125243.0      219.4773      224.37       218.36      224.48
# 731  102635321.0      221.9519      219.15       219.86      225.60
# ...

# %%
import hopsworks  
# creating hopsworks-project by passing project name and api-key
project = hopsworks.login(project=HOPSWORKS_PROJECT_NAME, api_key_value=HOPSWORKS_API_KEY)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/835736

# %%
# hopsworks-project.get-feature-store() gets pointer to the feature store
feature_store = project.get_feature_store()
# Out:
# 2024-08-05 16:02:48,142 WARNING: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#
# 2024-08-05 16:02:48,142 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.

# %%
FEATURE_GROUP_NAME = "time_series_daily_feature_group"
FEATURE_GROUP_VERSION =  3  # name and version of feature group

# creating feature-group-obj feature-store-obj.create()
# primary-key: unique identifier for each row in data
# event-time: is the column that stores the tiemstamp behind those events
feature_group = feature_store.get_or_create_feature_group(
    name=FEATURE_GROUP_NAME,
    version=FEATURE_GROUP_VERSION,
    description="Time-series data at daily frequency!",
    primary_key=["datetime"],
    event_time="datetime",
)

# %%
# save time-series data  to feature-group
feature_group.insert(ts_prices, write_options={"wait_for_job":False})
# Out:
# 2024-08-05 16:08:50,984 WARNING: FeatureGroupWarning: The ingested dataframe contains upper case letters in feature names: `['SMA_5', 'SMA_20', 'EMA_5', 'EMA_20']`. Feature names are sanitized to lower case in the feature store.
#
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/835736/fs/831559/fg/1072468
# Uploading Dataframe: 0.00% |          | Rows 0/735 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: time_series_daily_feature_group_3_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/835736/jobs/named/time_series_daily_feature_group_3_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x121df4e90>, None)
